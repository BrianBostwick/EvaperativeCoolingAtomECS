# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import maxwell

# %%
x = np.linspace(0, 60, 100) 
     
# Varying positional arguments 
y1 = maxwell.pdf(x, 2, 9) 
plt.plot(x, y1, "r--")
plt.show()
